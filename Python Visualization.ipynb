# %%
from overcooked_ai_py.agents.benchmarking import AgentEvaluator
from overcooked_ai_py.agents.agent import AgentPair, FixedPlanAgent, GreedyHumanModel, RandomAgent, SampleAgent
from overcooked_ai_py.visualization.state_visualizer import StateVisualizer

ae = AgentEvaluator.from_layout_name({"layout_name": "risky_cramped_room"}, {"horizon": 100})
trajs = ae.evaluate_human_model_pair()
# print(ae.env)
# print(ae.mdp.state_string)

action_probs = [ [RandomAgent(all_actions=True).action(state)[1]["action_probs"]]*2 for state in trajs["ep_states"][0]]
StateVisualizer().display_rendered_trajectory(trajs, ipython_display=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_29058/3442132664.py in <module>
#       4
#       5 ae = AgentEvaluator.from_layout_name({"layout_name": "risky_cramped_room"}, {"horizon": 100})
# ----> 6 trajs = ae.evaluate_human_model_pair()
#       7 # print(ae.env)
#       8 # print(ae.mdp.state_string)
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/benchmarking.py in evaluate_human_model_pair(self, num_games, display, native_eval)
#     225             num_games=num_games,
#     226             display=display,
# --> 227             native_eval=native_eval,
#     228         )
#     229
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/benchmarking.py in evaluate_agent_pair(self, agent_pair, num_games, game_length, start_state_fn, metadata_fn, metadata_info_fn, display, dir, display_phi, info, native_eval)
#     279                 info=info,
#     280                 metadata_fn=metadata_fn,
# --> 281                 metadata_info_fn=metadata_info_fn,
#     282             )
#     283
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/mdp/overcooked_env.py in get_rollouts(self, agent_pair, num_games, display, dir, final_state, display_phi, display_until, metadata_fn, metadata_info_fn, info)
#     530                 include_final_state=final_state,
#     531                 display_phi=display_phi,
# --> 532                 display_until=display_until,
#     533             )
#     534             (
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/mdp/overcooked_env.py in run_agents(self, agent_pair, include_final_state, display, dir, display_phi, display_until)
#     454
#     455             # Getting actions and action infos (optional) for both agents
# --> 456             joint_action_and_infos = agent_pair.joint_action(s_t)
#     457             a_t, a_info_t = zip(*joint_action_and_infos)
#     458             assert all(a in Action.ALL_ACTIONS for a in a_t)
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/agent.py in joint_action(self, state)
#     162             return joint_action_and_infos
#     163         else:
# --> 164             return super().joint_action(state)
#     165
#     166
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/agent.py in joint_action(self, state)
#     118
#     119     def joint_action(self, state):
# --> 120         actions_and_probs_n = tuple(a.action(state) for a in self.agents)
#     121         return actions_and_probs_n
#     122
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/agent.py in <genexpr>(.0)
#     118
#     119     def joint_action(self, state):
# --> 120         actions_and_probs_n = tuple(a.action(state) for a in self.agents)
#     121         return actions_and_probs_n
#     122
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/agent.py in action(self, state)
#     346
#     347     def action(self, state):
# --> 348         possible_motion_goals = self.ml_action(state)
#     349
#     350         # Once we have identified the motion goals for the medium
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/agent.py in ml_action(self, state)
#     569         motion_goals = [
#     570             mg
# --> 571             for mg in motion_goals
#     572             if self.mlam.motion_planner.is_valid_motion_start_goal_pair(
#     573                 player.pos_and_or, mg
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/agents/agent.py in <listcomp>(.0)
#     571             for mg in motion_goals
#     572             if self.mlam.motion_planner.is_valid_motion_start_goal_pair(
# --> 573                 player.pos_and_or, mg
#     574             )
#     575         ]
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/planning/planners.py in is_valid_motion_start_goal_pair(self, start_pos_and_or, goal_pos_and_or)
#     205             return False
#     206         # the valid motion start goal needs to be in the same connected component
# --> 207         if not self.positions_are_connected(start_pos_and_or, goal_pos_and_or):
#     208             return False
#     209         return True
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/planning/planners.py in positions_are_connected(self, start_pos_and_or, goal_pos_and_or)
#     254     def positions_are_connected(self, start_pos_and_or, goal_pos_and_or):
#     255         return self.graph_problem.are_in_same_cc(
# --> 256             start_pos_and_or, goal_pos_and_or
#     257         )
#     258
#
# ~/PycharmProjects/overcooked_ai/src/overcooked_ai_py/planning/search.py in are_in_same_cc(self, node1, node2)
#     310             len(node1_cc_index) == len(node2_cc_index) == 1
#     311         ), "Node 1 cc: {} \t Node 2 cc: {}".format(
# --> 312             node1_cc_index, node2_cc_index
#     313         )
#     314         return node1_cc_index[0] == node2_cc_index[0]
#
# AssertionError: Node 1 cc: [] 	 Node 2 cc: [0]
